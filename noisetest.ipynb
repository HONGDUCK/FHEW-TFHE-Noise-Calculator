# %%
from NoiseCal import *

# %%
data = """
        { BINFHE_PARAMSET     bits, cycOrder, latParam, modq,   modKS,  stdDev, Bks,        Bg, Brk, autoKeys,         keyDist } },
        { LPF_STD128_AP,        27,     2048,      556, 2048,   32768, STD_DEV,  64,       128,  64,       10, UNIFORM_TERNARY } },
        { LPF_STD128Q_AP,       25,     2048,      645, 2048,   65536, STD_DEV,  64,       128,  64,       10, UNIFORM_TERNARY } },
        { LPF_STD128_GINX,      27,     2048,      556, 2048,   32768, STD_DEV,  64,       128,  64,       10, UNIFORM_TERNARY } },
        { LPF_STD128Q_GINX,     25,     2048,      645, 2048,   65536, STD_DEV,  64,       128,  64,       10, UNIFORM_TERNARY } },
        { LPF_STD128_LMKCDEY,   27,     2048,      556, 2048,   32768, STD_DEV,  32,       512,  64,       10, UNIFORM_TERNARY } },
        { LPF_STD128Q_LMKCDEY,  25,     2048,      600, 2048,   32768, STD_DEV,  32,       128,  64,       10, UNIFORM_TERNARY } },
"""

# %% [markdown]
# # OpenFHE Original

# %%
openfhe = parse_data(data)

setDelta(openfhe[0], 6)
setDelta(openfhe[1], 4)
setDelta(openfhe[2], 6)
setDelta(openfhe[3], 4)
setDelta(openfhe[4], 0)
setDelta(openfhe[5], 4)

display_parameters_vector(*openfhe)
# Out:
# Parameter                           name    n     q       N logQ logQ_ks B_ks  \
#
# LPF_STD128_AP              LPF_STD128_AP  556  2048  1024.0   27    15.0  6.0
# LPF_STD128Q_AP            LPF_STD128Q_AP  645  2048  1024.0   25    16.0  6.0
# LPF_STD128_GINX          LPF_STD128_GINX  556  2048  1024.0   27    15.0  6.0
# LPF_STD128Q_GINX        LPF_STD128Q_GINX  645  2048  1024.0   25    16.0  6.0
# LPF_STD128_LMKCDEY    LPF_STD128_LMKCDEY  556  2048  1024.0   27    15.0  5.0
# LPF_STD128Q_LMKCDEY  LPF_STD128Q_LMKCDEY  600  2048  1024.0   25    15.0  5.0
#
# Parameter            B_g  B_r   w  t delta sigma  d_r  d_g d_ks index  \
#
# LPF_STD128_AP        7.0  6.0  10  0  64.0   3.2  2.0  3.0  3.0     0
# LPF_STD128Q_AP       7.0  6.0  10  0  16.0   3.2  2.0  3.0  3.0     1
# LPF_STD128_GINX      7.0  6.0  10  0  64.0   3.2  2.0  3.0  3.0     2
# LPF_STD128Q_GINX     7.0  6.0  10  0  16.0   3.2  2.0  3.0  3.0     3
# ...

# %% [markdown]
# # STD64

# %%
parsed_data_64  = parse_data(data)

setDigitsG(parsed_data_64[0], 2, 'AP')
setDigitsG(parsed_data_64[1], 3, 'AP')
setDigitsG(parsed_data_64[2], 2, 'GINX')
setDigitsG(parsed_data_64[3], 3, 'GINX')
setDigitsG(parsed_data_64[4], 2, 'LMKCDEY')
setDigitsG(parsed_data_64[5], 3, 'LMKCDEY')

setCutoff(parsed_data_64[0], 11)
setCutoff(parsed_data_64[1], 13)
setCutoff(parsed_data_64[2],  4)
setCutoff(parsed_data_64[3], 10)
setCutoff(parsed_data_64[4],  9)
setCutoff(parsed_data_64[5], 12)

display_parameters_vector(*parsed_data_64)
# Out:
# Parameter                           name    n     q       N logQ logQ_ks B_ks  \
#
# LPF_STD128_AP              LPF_STD128_AP  556  2048  1024.0   27    15.0  6.0
# LPF_STD128Q_AP            LPF_STD128Q_AP  645  2048  1024.0   25    16.0  6.0
# LPF_STD128_GINX          LPF_STD128_GINX  556  2048  1024.0   27    15.0  6.0
# LPF_STD128Q_GINX        LPF_STD128Q_GINX  645  2048  1024.0   25    16.0  6.0
# LPF_STD128_LMKCDEY    LPF_STD128_LMKCDEY  556  2048  1024.0   27    15.0  5.0
# LPF_STD128Q_LMKCDEY  LPF_STD128Q_LMKCDEY  600  2048  1024.0   25    15.0  5.0
#
# Parameter            B_g  B_r   w   t   delta sigma  d_r d_g d_ks index  \
#
# LPF_STD128_AP        8.0  6.0  10  11  2048.0   3.2  2.0   2  3.0     0
# LPF_STD128Q_AP       6.0  6.0  10  13   128.0   3.2  2.0   3  3.0     1
# LPF_STD128_GINX      8.0  6.0  10   4  2048.0   3.2  2.0   2  3.0     2
# LPF_STD128Q_GINX     6.0  6.0  10  10   128.0   3.2  2.0   3  3.0     3
# ...

# %% [markdown]
# # STD96

# %%
parsed_data_96 = parse_data(data)

setDigitsG(parsed_data_96[0], 2, 'AP')
setDigitsG(parsed_data_96[1], 3, 'AP')
setDigitsG(parsed_data_96[2], 3, 'GINX')
setDigitsG(parsed_data_96[3], 4, 'GINX')
setDigitsG(parsed_data_96[4], 3, 'LMKCDEY')
setDigitsG(parsed_data_96[5], 3, 'LMKCDEY')

setCutoff(parsed_data_96[0], 3)
setCutoff(parsed_data_96[1], 9)
setCutoff(parsed_data_96[2], 11)
setCutoff(parsed_data_96[3], 10)
setCutoff(parsed_data_96[4], 11)
setCutoff(parsed_data_96[5], 7)

display_parameters_vector(*parsed_data_96)
# Out:
# Parameter                           name    n     q       N logQ logQ_ks B_ks  \
#
# LPF_STD128_AP              LPF_STD128_AP  556  2048  1024.0   27    15.0  6.0
# LPF_STD128Q_AP            LPF_STD128Q_AP  645  2048  1024.0   25    16.0  6.0
# LPF_STD128_GINX          LPF_STD128_GINX  556  2048  1024.0   27    15.0  6.0
# LPF_STD128Q_GINX        LPF_STD128Q_GINX  645  2048  1024.0   25    16.0  6.0
# LPF_STD128_LMKCDEY    LPF_STD128_LMKCDEY  556  2048  1024.0   27    15.0  5.0
# LPF_STD128Q_LMKCDEY  LPF_STD128Q_LMKCDEY  600  2048  1024.0   25    15.0  5.0
#
# Parameter            B_g  B_r   w   t   delta sigma  d_r d_g d_ks index  \
#
# LPF_STD128_AP        8.0  6.0  10   3  2048.0   3.2  2.0   2  3.0     0
# LPF_STD128Q_AP       6.0  6.0  10   9   128.0   3.2  2.0   3  3.0     1
# LPF_STD128_GINX      6.0  6.0  10  11   512.0   3.2  2.0   3  3.0     2
# LPF_STD128Q_GINX     5.0  6.0  10  10    32.0   3.2  2.0   4  3.0     3
# ...

# %% [markdown]
# # STD128

# %%
parsed_data_128 = parse_data(data)

DigitsG = 3
Cutoff  = 4

setDigitsG(parsed_data_128[0], 3, 'AP')
setDigitsG(parsed_data_128[1], 3, 'AP')
setDigitsG(parsed_data_128[2], 3, 'GINX')
setDigitsG(parsed_data_128[3], 4, 'GINX')
setDigitsG(parsed_data_128[4], 3, 'LMKCDEY')
setDigitsG(parsed_data_128[5], 4, 'LMKCDEY')

setCutoff(parsed_data_128[0], 9)
setCutoff(parsed_data_128[1], 5)
setCutoff(parsed_data_128[2], 9)
setCutoff(parsed_data_128[3], 8)
setCutoff(parsed_data_128[4], 9)
setCutoff(parsed_data_128[5], 8)

display_parameters_vector(*parsed_data_128)
# Out:
# Parameter                           name    n     q       N logQ logQ_ks B_ks  \
#
# LPF_STD128_AP              LPF_STD128_AP  556  2048  1024.0   27    15.0  6.0
# LPF_STD128Q_AP            LPF_STD128Q_AP  645  2048  1024.0   25    16.0  6.0
# LPF_STD128_GINX          LPF_STD128_GINX  556  2048  1024.0   27    15.0  6.0
# LPF_STD128Q_GINX        LPF_STD128Q_GINX  645  2048  1024.0   25    16.0  6.0
# LPF_STD128_LMKCDEY    LPF_STD128_LMKCDEY  556  2048  1024.0   27    15.0  5.0
# LPF_STD128Q_LMKCDEY  LPF_STD128Q_LMKCDEY  600  2048  1024.0   25    15.0  5.0
#
# Parameter            B_g  B_r   w  t  delta sigma  d_r d_g d_ks index  \
#
# LPF_STD128_AP        6.0  6.0  10  9  512.0   3.2  2.0   3  3.0     0
# LPF_STD128Q_AP       6.0  6.0  10  5  128.0   3.2  2.0   3  3.0     1
# LPF_STD128_GINX      6.0  6.0  10  9  512.0   3.2  2.0   3  3.0     2
# LPF_STD128Q_GINX     5.0  6.0  10  8   32.0   3.2  2.0   4  3.0     3
# ...
